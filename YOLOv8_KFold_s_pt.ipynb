# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.195-py3-none-any.whl (618 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.9/618.9 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.15.2+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->ultralytics) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->ultralytics) (17.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.0.195

# %%
import datetime
import shutil
from pathlib import Path
from collections import Counter

import yaml
import numpy as np
import pandas as pd
from ultralytics import YOLO
from sklearn.model_selection import KFold

# %%
# !unzip "/content/drive/MyDrive/dataset_yolo.zip"
# Out:
# Archive:  /content/drive/MyDrive/dataset_yolo.zip
#    creating: dataset/
#   inflating: dataset/data.yaml
#    creating: dataset/images/
#   inflating: dataset/images/pothole1.jpg
#   inflating: dataset/images/pothole10.jpg
#   inflating: dataset/images/pothole100.jpg
#   inflating: dataset/images/pothole101.jpg
#   inflating: dataset/images/pothole102.jpg
#   inflating: dataset/images/pothole103.jpg
#   inflating: dataset/images/pothole104.jpg
#   inflating: dataset/images/pothole105.jpg
#   inflating: dataset/images/pothole106.jpg
#   inflating: dataset/images/pothole107.jpg
#   inflating: dataset/images/pothole108.jpg
#   inflating: dataset/images/pothole109.jpg
#   inflating: dataset/images/pothole11.jpg
#   inflating: dataset/images/pothole110.jpg
#   inflating: dataset/images/pothole111.jpg
#   inflating: dataset/images/pothole112.jpg
#   inflating: dataset/images/pothole113.jpg
#   inflating: dataset/images/pothole114.jpg
#   inflating: dataset/images/pothole115.jpg
#   inflating: dataset/images/pothole116.jpg
#   inflating: dataset/images/pothole117.jpg
#   inflating: dataset/images/pothole118.jpg
#   inflating: dataset/images/pothole119.jpg
#   inflating: dataset/images/pothole12.jpg
#   inflating: dataset/images/pothole120.jpg
#   inflating: dataset/images/pothole121.jpg
#   inflating: dataset/images/pothole122.jpg
#   inflating: dataset/images/pothole123.jpg
#   inflating: dataset/images/pothole124.jpg
#   inflating: dataset/images/pothole125.jpg
#   inflating: dataset/images/pothole126.jpg
#   inflating: dataset/images/pothole127.jpg
#   inflating: dataset/images/pothole128.jpg
#   inflating: dataset/images/pothole129.jpg
#   inflating: dataset/images/pothole13.jpg
#   inflating: dataset/images/pothole130.jpg
#   inflating: dataset/images/pothole131.jpg
#   inflating: dataset/images/pothole132.jpg
#   inflating: dataset/images/pothole133.jpg
#   inflating: dataset/images/pothole134.jpg
#   inflating: dataset/images/pothole135.jpg
#   inflating: dataset/images/pothole136.jpg
#   inflating: dataset/images/pothole137.jpg
#   inflating: dataset/images/pothole138.jpg
#   inflating: dataset/images/pothole139.jpg
#   inflating: dataset/images/pothole14.jpg
#   inflating: dataset/images/pothole140.jpg
#   inflating: dataset/images/pothole141.jpg
#   inflating: dataset/images/pothole142.jpg
#   inflating: dataset/images/pothole143.jpg
#   inflating: dataset/images/pothole144.jpg
#   inflating: dataset/images/pothole145.jpg
#   inflating: dataset/images/pothole146.jpg
#   inflating: dataset/images/pothole147.jpg
#   inflating: dataset/images/pothole148.jpg
#   inflating: dataset/images/pothole149.jpg
#   inflating: dataset/images/pothole15.jpg
#   inflating: dataset/images/pothole150.jpg
#   inflating: dataset/images/pothole151.jpg
#   inflating: dataset/images/pothole152.jpg
#   inflating: dataset/images/speedbreaker121.jpg
#   inflating: dataset/images/speedbreaker122.jpg
#   inflating: dataset/images/speedbreaker123.jpg
#   inflating: dataset/images/speedbreaker124.jpg
#   inflating: dataset/images/speedbreaker125.jpg
#   inflating: dataset/images/speedbreaker126.jpg
#   inflating: dataset/images/speedbreaker127.jpg
#   inflating: dataset/images/speedbreaker128.jpg
#   inflating: dataset/images/speedbreaker129.jpg
#   inflating: dataset/images/speedbreaker13.jpg
#   inflating: dataset/images/speedbreaker130.jpg
#   inflating: dataset/images/speedbreaker131.jpg
#   inflating: dataset/images/speedbreaker132.jpg
#   inflating: dataset/images/speedbreaker133.jpg
#   inflating: dataset/images/speedbreaker134.jpg
#   inflating: dataset/images/speedbreaker135.jpg
#   inflating: dataset/images/speedbreaker136.jpg
#   inflating: dataset/images/speedbreaker137.jpg
#   inflating: dataset/images/speedbreaker138.jpg
#   inflating: dataset/images/speedbreaker139.jpg
#   inflating: dataset/images/speedbreaker14.jpg
#   inflating: dataset/images/speedbreaker140.jpg
#   inflating: dataset/images/speedbreaker141.jpg
#   inflating: dataset/images/speedbreaker142.jpg
#   inflating: dataset/images/speedbreaker143.jpg
#   inflating: dataset/images/speedbreaker144.jpg
#   inflating: dataset/images/speedbreaker145.jpg
#   inflating: dataset/images/speedbreaker146.jpg
#   inflating: dataset/images/speedbreaker147.jpg
#   inflating: dataset/images/speedbreaker148.jpg
#   inflating: dataset/images/speedbreaker149.jpg
#   inflating: dataset/images/speedbreaker15.jpg
#   inflating: dataset/images/speedbreaker150.jpg
#   inflating: dataset/images/speedbreaker151.jpg
#   inflating: dataset/images/speedbreaker152.jpg
#   inflating: dataset/images/speedbreaker153.jpg
#   inflating: dataset/images/speedbreaker154.jpg
#   inflating: dataset/images/speedbreaker155.jpg
#   inflating: dataset/images/speedbreaker156.jpg
#   inflating: dataset/images/speedbreaker157.jpg
#   inflating: dataset/images/speedbreaker158.jpg
#   inflating: dataset/images/speedbreaker159.jpg
#   inflating: dataset/images/speedbreaker16.jpg
#   inflating: dataset/images/speedbreaker160.jpg
#   inflating: dataset/images/speedbreaker161.jpg
#   inflating: dataset/images/speedbreaker162.jpg
#   inflating: dataset/images/speedbreaker163.jpg
#   inflating: dataset/images/speedbreaker164.jpg
#   inflating: dataset/images/speedbreaker165.jpg
#   inflating: dataset/images/speedbreaker166.jpg
#   inflating: dataset/images/speedbreaker167.jpg
#   inflating: dataset/images/speedbreaker168.jpg
#   inflating: dataset/images/speedbreaker169.jpg
#   inflating: dataset/images/speedbreaker17.jpg
#   inflating: dataset/images/speedbreaker170.jpg
#   inflating: dataset/images/speedbreaker171.jpg
#   inflating: dataset/images/speedbreaker172.jpg
#   inflating: dataset/images/speedbreaker173.jpg
#   inflating: dataset/images/speedbreaker174.jpg
#   inflating: dataset/images/speedbreaker175.jpg
#   inflating: dataset/images/speedbreaker176.jpg
#   inflating: dataset/images/speedbreaker177.jpg
#   inflating: dataset/images/speedbreaker178.jpg
#   inflating: dataset/images/speedbreaker179.jpg
#   inflating: dataset/images/speedbreaker18.jpg
#   inflating: dataset/images/speedbreaker180.jpg
#   inflating: dataset/images/speedbreaker181.jpg
#   inflating: dataset/images/speedbreaker182.jpg
#   inflating: dataset/images/speedbreaker183.jpg
#   inflating: dataset/images/speedbreaker184.jpg
#   inflating: dataset/images/speedbreaker185.jpg
#   inflating: dataset/images/speedbreaker186.jpg
#   inflating: dataset/images/speedbreaker187.jpg
#   inflating: dataset/images/speedbreaker188.jpg
#   inflating: dataset/images/speedbreaker189.jpg
#   inflating: dataset/images/speedbreaker19.jpg
#   inflating: dataset/images/speedbreaker190.jpg
#   inflating: dataset/images/speedbreaker191.jpg
#   inflating: dataset/images/speedbreaker192.jpg
#   inflating: dataset/images/speedbreaker193.jpg
#   inflating: dataset/images/speedbreaker194.jpg
#   inflating: dataset/images/speedbreaker195.jpg
#   inflating: dataset/images/speedbreaker196.jpg
#   inflating: dataset/images/speedbreaker197.jpg
#   inflating: dataset/images/speedbreaker198.jpg
#   inflating: dataset/images/speedbreaker199.jpg
#   inflating: dataset/images/speedbreaker2.jpg
#   inflating: dataset/images/speedbreaker20.jpg
#   inflating: dataset/images/speedbreaker200.jpg
#   inflating: dataset/images/speedbreaker201.jpg
#   inflating: dataset/images/speedbreaker202.jpg
#   inflating: dataset/images/speedbreaker203.jpg
#   inflating: dataset/images/speedbreaker204.jpg
#   inflating: dataset/images/speedbreaker205.jpg
#   inflating: dataset/images/speedbreaker206.jpg
#   inflating: dataset/images/speedbreaker207.jpg
#   inflating: dataset/images/speedbreaker208.jpg
#   inflating: dataset/images/speedbreaker209.jpg
#   inflating: dataset/images/speedbreaker21.jpg
#   inflating: dataset/images/speedbreaker210.jpg
#   inflating: dataset/images/speedbreaker211.jpg
#   inflating: dataset/images/speedbreaker212.jpg
#   inflating: dataset/images/speedbreaker213.jpg
#   inflating: dataset/images/speedbreaker214.jpg
#   inflating: dataset/images/speedbreaker215.jpg
#   inflating: dataset/images/speedbreaker216.jpg
#   inflating: dataset/images/speedbreaker217.jpg
#   inflating: dataset/images/speedbreaker218.jpg
#   inflating: dataset/images/speedbreaker219.jpg
#   inflating: dataset/images/speedbreaker22.jpg
#   inflating: dataset/images/speedbreaker220.jpg
#   inflating: dataset/images/speedbreaker221.jpg
#   inflating: dataset/images/speedbreaker222.jpg
#   inflating: dataset/images/speedbreaker223.jpg
#   inflating: dataset/images/speedbreaker224.jpg
#   inflating: dataset/images/speedbreaker225.jpg
#   inflating: dataset/images/speedbreaker226.jpg
#   inflating: dataset/images/speedbreaker227.jpg
#   inflating: dataset/images/speedbreaker228.jpg
#   inflating: dataset/images/speedbreaker229.jpg
#   inflating: dataset/images/speedbreaker23.jpg
#   inflating: dataset/images/speedbreaker230.jpg
#   inflating: dataset/images/speedbreaker231.jpg
#   inflating: dataset/images/speedbreaker232.jpg
#   inflating: dataset/images/speedbreaker233.jpg
#   inflating: dataset/images/speedbreaker234.jpg
#   inflating: dataset/images/speedbreaker235.jpg
#   inflating: dataset/images/speedbreaker236.jpg
#   inflating: dataset/images/speedbreaker237.jpg
#   inflating: dataset/images/speedbreaker238.jpg
#   inflating: dataset/images/speedbreaker239.jpg
#   inflating: dataset/images/speedbreaker24.jpg
#   inflating: dataset/images/speedbreaker240.jpg
#   inflating: dataset/images/speedbreaker241.jpg
#   inflating: dataset/images/speedbreaker242.jpg
#   inflating: dataset/images/speedbreaker243.jpg
#   inflating: dataset/images/speedbreaker244.jpg
#   inflating: dataset/images/speedbreaker245.jpg
#   inflating: dataset/images/speedbreaker246.jpg
#   inflating: dataset/images/speedbreaker247.jpg
#   inflating: dataset/images/speedbreaker248.jpg
#   inflating: dataset/images/speedbreaker249.jpg
#   inflating: dataset/images/speedbreaker25.jpg
#   inflating: dataset/images/speedbreaker250.jpg
#   inflating: dataset/images/speedbreaker251.jpg
#   inflating: dataset/images/speedbreaker252.jpg
#   inflating: dataset/images/speedbreaker253.jpg
#   inflating: dataset/images/speedbreaker254.jpg
#   inflating: dataset/images/speedbreaker255.jpg
#   inflating: dataset/images/speedbreaker256.jpg
#   inflating: dataset/images/speedbreaker257.jpg
#   inflating: dataset/images/speedbreaker258.jpg
#   inflating: dataset/images/speedbreaker259.jpg
#   inflating: dataset/images/speedbreaker26.jpg
#   inflating: dataset/images/speedbreaker260.jpg
#   inflating: dataset/images/speedbreaker261.jpg
#   inflating: dataset/images/speedbreaker262.jpg
#   inflating: dataset/images/speedbreaker263.jpg
#   inflating: dataset/images/speedbreaker264.jpg
#   inflating: dataset/images/speedbreaker265.jpg
#   inflating: dataset/images/speedbreaker266.jpg
#   inflating: dataset/images/speedbreaker267.jpg
#   inflating: dataset/images/speedbreaker268.jpg
#   inflating: dataset/images/speedbreaker269.jpg
#   inflating: dataset/images/speedbreaker27.jpg
#   inflating: dataset/images/speedbreaker270.jpg
#   inflating: dataset/images/speedbreaker271.jpg
#   inflating: dataset/images/speedbreaker272.jpg
#   inflating: dataset/images/speedbreaker273.jpg
#   inflating: dataset/images/speedbreaker274.jpg
#   inflating: dataset/images/speedbreaker275.jpg
#   inflating: dataset/images/speedbreaker276.jpg
#   inflating: dataset/images/speedbreaker277.jpg
#   inflating: dataset/images/speedbreaker278.jpg
#   inflating: dataset/images/speedbreaker279.jpg
#   inflating: dataset/images/speedbreaker28.jpg
#   inflating: dataset/images/speedbreaker280.jpg
#   inflating: dataset/images/speedbreaker281.jpg
#   inflating: dataset/images/speedbreaker282.jpg
#   inflating: dataset/images/speedbreaker283.jpg
#   inflating: dataset/images/speedbreaker284.jpg
#   inflating: dataset/images/speedbreaker285.jpg
#   inflating: dataset/images/speedbreaker286.jpg
#   inflating: dataset/images/speedbreaker287.jpg
#   inflating: dataset/images/speedbreaker288.jpg
#   inflating: dataset/images/speedbreaker289.jpg
#   inflating: dataset/images/speedbreaker29.jpg
#   inflating: dataset/images/speedbreaker290.jpg
#   inflating: dataset/images/speedbreaker291.jpg
#   inflating: dataset/images/speedbreaker292.jpg
#   inflating: dataset/images/speedbreaker293.jpg
#   inflating: dataset/images/speedbreaker294.jpg
#   inflating: dataset/images/speedbreaker295.jpg
#   inflating: dataset/images/speedbreaker296.jpg
#   inflating: dataset/images/speedbreaker297.jpg
#   inflating: dataset/images/speedbreaker298.jpg
#   inflating: dataset/images/speedbreaker299.jpg
#   inflating: dataset/images/speedbreaker3.jpg
#   inflating: dataset/images/speedbreaker30.jpg
#   inflating: dataset/images/speedbreaker300.jpg
#   inflating: dataset/images/speedbreaker301.jpg
#   inflating: dataset/images/speedbreaker302.jpg
#   inflating: dataset/images/speedbreaker303.jpg
#   inflating: dataset/images/speedbreaker304.jpg
#   inflating: dataset/images/speedbreaker305.jpg
#   inflating: dataset/images/speedbreaker306.jpg
#   inflating: dataset/images/speedbreaker307.jpg
#   inflating: dataset/images/speedbreaker308.jpg
#   inflating: dataset/images/speedbreaker309.jpg
#   inflating: dataset/images/speedbreaker31.jpg
#   inflating: dataset/images/speedbreaker310.jpg
#   inflating: dataset/images/speedbreaker311.jpg
#   inflating: dataset/images/speedbreaker312.jpg
#   inflating: dataset/images/speedbreaker313.jpg
#   inflating: dataset/images/speedbreaker314.jpg
#   inflating: dataset/images/speedbreaker315.jpg
#   inflating: dataset/images/speedbreaker316.jpg
#   inflating: dataset/images/speedbreaker317.jpg
#   inflating: dataset/images/speedbreaker318.jpg
#   inflating: dataset/images/speedbreaker319.jpg
#   inflating: dataset/images/speedbreaker32.jpg
#   inflating: dataset/images/speedbreaker320.jpg
#   inflating: dataset/images/speedbreaker321.jpg
#   inflating: dataset/images/speedbreaker322.jpg
#   inflating: dataset/images/speedbreaker323.jpg
#   inflating: dataset/images/speedbreaker324.jpg
#   inflating: dataset/images/speedbreaker325.jpg
#   inflating: dataset/images/speedbreaker326.jpg
#   inflating: dataset/images/speedbreaker327.jpg
#   inflating: dataset/images/speedbreaker328.jpg
#   inflating: dataset/images/speedbreaker329.jpg
#   inflating: dataset/images/speedbreaker33.jpg
#   inflating: dataset/images/speedbreaker330.jpg
#   inflating: dataset/images/speedbreaker331.jpg
#   inflating: dataset/images/speedbreaker332.jpg
#   inflating: dataset/images/speedbreaker333.jpg
#   inflating: dataset/images/speedbreaker334.jpg
#   inflating: dataset/images/speedbreaker335.jpg
#   inflating: dataset/images/speedbreaker336.jpg
#   inflating: dataset/images/speedbreaker337.jpg
#   inflating: dataset/images/speedbreaker338.jpg
#   inflating: dataset/images/speedbreaker339.jpg
#   inflating: dataset/images/speedbreaker34.jpg
#   inflating: dataset/images/speedbreaker340.jpg
#   inflating: dataset/images/speedbreaker341.jpg
#   inflating: dataset/images/speedbreaker342.jpg
#   inflating: dataset/images/speedbreaker343.jpg
#   inflating: dataset/images/speedbreaker344.jpg
#   inflating: dataset/images/speedbreaker345.jpg
#   inflating: dataset/images/speedbreaker346.jpg
#   inflating: dataset/images/speedbreaker347.jpg
#   inflating: dataset/images/speedbreaker348.jpg
#   inflating: dataset/images/speedbreaker349.jpg
#   inflating: dataset/images/speedbreaker35.jpg
#   inflating: dataset/images/speedbreaker350.jpg
#   inflating: dataset/images/speedbreaker351.jpg
#   inflating: dataset/images/speedbreaker352.jpg
#   inflating: dataset/images/speedbreaker353.jpg
#   inflating: dataset/images/speedbreaker354.jpg
#   inflating: dataset/images/speedbreaker355.jpg
#   inflating: dataset/images/speedbreaker356.jpg
#   inflating: dataset/images/speedbreaker357.jpg
#   inflating: dataset/images/speedbreaker358.jpg
#   inflating: dataset/images/speedbreaker359.jpg
#   inflating: dataset/images/speedbreaker36.jpg
#   inflating: dataset/images/speedbreaker360.jpg
#   inflating: dataset/images/speedbreaker361.jpg
#   inflating: dataset/images/speedbreaker362.jpg
#   inflating: dataset/images/speedbreaker363.jpg
#   inflating: dataset/images/speedbreaker364.jpg
#   inflating: dataset/images/speedbreaker365.jpg
#   inflating: dataset/images/speedbreaker366.jpg
#   inflating: dataset/images/speedbreaker367.jpg
#   inflating: dataset/images/speedbreaker368.jpg
#   inflating: dataset/images/speedbreaker369.jpg
#   inflating: dataset/images/speedbreaker37.jpg
#   inflating: dataset/images/speedbreaker370.jpg
#   inflating: dataset/images/speedbreaker371.jpg
#   inflating: dataset/images/speedbreaker372.jpg
#   inflating: dataset/images/speedbreaker373.jpg
#   inflating: dataset/images/speedbreaker374.jpg
#   inflating: dataset/images/speedbreaker375.jpg
#   inflating: dataset/images/speedbreaker376.jpg
#   inflating: dataset/images/speedbreaker377.jpg
#   inflating: dataset/images/speedbreaker378.jpg
#   inflating: dataset/images/speedbreaker379.jpg
#   inflating: dataset/images/speedbreaker38.jpg
#   inflating: dataset/images/speedbreaker380.jpg
#   inflating: dataset/images/speedbreaker381.jpg
#   inflating: dataset/images/speedbreaker382.jpg
#   inflating: dataset/images/speedbreaker383.jpg
#   inflating: dataset/images/speedbreaker384.jpg
#   inflating: dataset/images/speedbreaker385.jpg
#   inflating: dataset/images/speedbreaker386.jpg
#   inflating: dataset/images/speedbreaker387.jpg
#   inflating: dataset/images/speedbreaker388.jpg
#   inflating: dataset/images/speedbreaker389.jpg
#   inflating: dataset/images/speedbreaker39.jpg
#   inflating: dataset/images/speedbreaker390.jpg
#   inflating: dataset/images/speedbreaker391.jpg
#   inflating: dataset/images/speedbreaker392.jpg
#   inflating: dataset/images/speedbreaker393.jpg
#   inflating: dataset/images/speedbreaker394.jpg
#   inflating: dataset/images/speedbreaker395.jpg
#   inflating: dataset/images/speedbreaker396.jpg
#   inflating: dataset/images/speedbreaker397.jpg
#   inflating: dataset/images/speedbreaker398.jpg
#   inflating: dataset/images/speedbreaker399.jpg
#   inflating: dataset/images/speedbreaker4.jpg
#   inflating: dataset/images/speedbreaker40.jpg
#   inflating: dataset/images/speedbreaker400.jpg
#   inflating: dataset/images/speedbreaker401.jpg
#   inflating: dataset/images/speedbreaker402.jpg
#   inflating: dataset/images/speedbreaker403.jpg
#   inflating: dataset/images/speedbreaker404.jpg
#   inflating: dataset/images/speedbreaker405.jpg
#   inflating: dataset/images/speedbreaker406.jpg
#   inflating: dataset/images/speedbreaker407.jpg
#   inflating: dataset/images/speedbreaker408.jpg
#   inflating: dataset/images/speedbreaker409.jpg
#   inflating: dataset/images/speedbreaker41.jpg
#   inflating: dataset/images/speedbreaker410.jpg
#   inflating: dataset/images/speedbreaker411.jpg
#   inflating: dataset/images/speedbreaker412.jpg
#   inflating: dataset/images/speedbreaker413.jpg
#   inflating: dataset/images/speedbreaker414.jpg
#   inflating: dataset/images/speedbreaker415.jpg
#   inflating: dataset/images/speedbreaker416.jpg
#   inflating: dataset/images/speedbreaker417.jpg
#   inflating: dataset/images/speedbreaker418.jpg
#   inflating: dataset/images/speedbreaker419.jpg
#   inflating: dataset/images/speedbreaker42.jpg
#   inflating: dataset/images/speedbreaker420.jpg
#   inflating: dataset/images/speedbreaker421.jpg
#   inflating: dataset/images/speedbreaker422.jpg
#   inflating: dataset/images/speedbreaker423.jpg
#   inflating: dataset/images/speedbreaker424.jpg
#   inflating: dataset/images/speedbreaker425.jpg
#   inflating: dataset/images/speedbreaker426.jpg
#   inflating: dataset/images/speedbreaker427.jpg
#   inflating: dataset/images/speedbreaker428.jpg
#   inflating: dataset/images/speedbreaker429.jpg
#   inflating: dataset/images/speedbreaker43.jpg
#   inflating: dataset/images/speedbreaker430.jpg
#   inflating: dataset/images/speedbreaker431.jpg
#   inflating: dataset/images/speedbreaker432.jpg
#   inflating: dataset/images/speedbreaker433.jpg
#   inflating: dataset/images/speedbreaker434.jpg
#   inflating: dataset/images/speedbreaker435.jpg
#   inflating: dataset/images/speedbreaker436.jpg
#   inflating: dataset/images/speedbreaker437.jpg
#   inflating: dataset/images/speedbreaker438.jpg
#   inflating: dataset/images/speedbreaker439.jpg
#   inflating: dataset/images/speedbreaker44.jpg
#   inflating: dataset/images/speedbreaker440.jpg
#   inflating: dataset/images/speedbreaker441.jpg
#   inflating: dataset/images/speedbreaker442.jpg
#   inflating: dataset/images/speedbreaker443.jpg
#   inflating: dataset/images/speedbreaker444.jpg
#   inflating: dataset/images/speedbreaker445.jpg
#   inflating: dataset/images/speedbreaker446.jpg
#   inflating: dataset/images/speedbreaker447.jpg
#   inflating: dataset/images/speedbreaker448.jpg
#   inflating: dataset/images/speedbreaker449.jpg
#   inflating: dataset/images/speedbreaker45.jpg
#   inflating: dataset/images/speedbreaker450.jpg
#   inflating: dataset/images/speedbreaker451.jpg
#   inflating: dataset/images/speedbreaker452.jpg
#   inflating: dataset/images/speedbreaker453.jpg
#   inflating: dataset/images/speedbreaker454.jpg
#   inflating: dataset/images/speedbreaker455.jpg
#   inflating: dataset/images/speedbreaker456.jpg
#   inflating: dataset/images/speedbreaker457.jpg
#   inflating: dataset/images/speedbreaker458.jpg
#   inflating: dataset/images/speedbreaker459.jpg
#   inflating: dataset/images/speedbreaker46.jpg
#   inflating: dataset/images/speedbreaker460.jpg
#   inflating: dataset/images/speedbreaker461.jpg
#   inflating: dataset/images/speedbreaker462.jpg
#   inflating: dataset/images/speedbreaker463.jpg
#   inflating: dataset/images/speedbreaker464.jpg
#   inflating: dataset/images/speedbreaker465.jpg
#   inflating: dataset/images/speedbreaker466.jpg
#   inflating: dataset/images/speedbreaker467.jpg
#   inflating: dataset/images/speedbreaker468.jpg
#   inflating: dataset/images/speedbreaker469.jpg
# ...
#   inflating: dataset/labels/speedbreaker354.txt
#   inflating: dataset/labels/speedbreaker355.txt
#   inflating: dataset/labels/speedbreaker356.txt
#   inflating: dataset/labels/speedbreaker357.txt
#   inflating: dataset/labels/speedbreaker358.txt
#   inflating: dataset/labels/speedbreaker359.txt
#   inflating: dataset/labels/speedbreaker36.txt
#   inflating: dataset/labels/speedbreaker360.txt
#   inflating: dataset/labels/speedbreaker361.txt
#   inflating: dataset/labels/speedbreaker362.txt
#   inflating: dataset/labels/speedbreaker363.txt
#   inflating: dataset/labels/speedbreaker364.txt
#   inflating: dataset/labels/speedbreaker365.txt
#   inflating: dataset/labels/speedbreaker366.txt
#   inflating: dataset/labels/speedbreaker367.txt
#   inflating: dataset/labels/speedbreaker368.txt
#   inflating: dataset/labels/speedbreaker369.txt
#   inflating: dataset/labels/speedbreaker37.txt
#   inflating: dataset/labels/speedbreaker370.txt
#   inflating: dataset/labels/speedbreaker371.txt
#   inflating: dataset/labels/speedbreaker372.txt
#   inflating: dataset/labels/speedbreaker373.txt
#   inflating: dataset/labels/speedbreaker374.txt
#   inflating: dataset/labels/speedbreaker375.txt
#   inflating: dataset/labels/speedbreaker376.txt
#   inflating: dataset/labels/speedbreaker377.txt
#   inflating: dataset/labels/speedbreaker378.txt
#   inflating: dataset/labels/speedbreaker379.txt
#   inflating: dataset/labels/speedbreaker38.txt
#   inflating: dataset/labels/speedbreaker380.txt
#   inflating: dataset/labels/speedbreaker381.txt
#   inflating: dataset/labels/speedbreaker382.txt
#   inflating: dataset/labels/speedbreaker383.txt
#   inflating: dataset/labels/speedbreaker384.txt
#   inflating: dataset/labels/speedbreaker385.txt
#   inflating: dataset/labels/speedbreaker386.txt
#   inflating: dataset/labels/speedbreaker387.txt
#   inflating: dataset/labels/speedbreaker388.txt
#   inflating: dataset/labels/speedbreaker389.txt
#   inflating: dataset/labels/speedbreaker39.txt
#   inflating: dataset/labels/speedbreaker390.txt
#   inflating: dataset/labels/speedbreaker391.txt
#   inflating: dataset/labels/speedbreaker392.txt
#   inflating: dataset/labels/speedbreaker393.txt
#   inflating: dataset/labels/speedbreaker394.txt
#   inflating: dataset/labels/speedbreaker395.txt
#   inflating: dataset/labels/speedbreaker396.txt
#   inflating: dataset/labels/speedbreaker397.txt
#   inflating: dataset/labels/speedbreaker398.txt
#   inflating: dataset/labels/speedbreaker399.txt
#   inflating: dataset/labels/speedbreaker4.txt
#   inflating: dataset/labels/speedbreaker40.txt
#   inflating: dataset/labels/speedbreaker400.txt
#   inflating: dataset/labels/speedbreaker401.txt
#   inflating: dataset/labels/speedbreaker402.txt
#   inflating: dataset/labels/speedbreaker403.txt
#   inflating: dataset/labels/speedbreaker404.txt
#   inflating: dataset/labels/speedbreaker405.txt
#   inflating: dataset/labels/speedbreaker406.txt
#   inflating: dataset/labels/speedbreaker407.txt
#   inflating: dataset/labels/speedbreaker408.txt
#   inflating: dataset/labels/speedbreaker409.txt
#   inflating: dataset/labels/speedbreaker41.txt
#   inflating: dataset/labels/speedbreaker410.txt
#   inflating: dataset/labels/speedbreaker411.txt
#   inflating: dataset/labels/speedbreaker412.txt
#   inflating: dataset/labels/speedbreaker413.txt
#   inflating: dataset/labels/speedbreaker414.txt
#   inflating: dataset/labels/speedbreaker415.txt
#   inflating: dataset/labels/speedbreaker416.txt
#   inflating: dataset/labels/speedbreaker417.txt
#   inflating: dataset/labels/speedbreaker418.txt
#   inflating: dataset/labels/speedbreaker419.txt
#   inflating: dataset/labels/speedbreaker42.txt
#   inflating: dataset/labels/speedbreaker420.txt
#   inflating: dataset/labels/speedbreaker421.txt
#   inflating: dataset/labels/speedbreaker422.txt
#   inflating: dataset/labels/speedbreaker423.txt
#   inflating: dataset/labels/speedbreaker424.txt
#   inflating: dataset/labels/speedbreaker425.txt
#   inflating: dataset/labels/speedbreaker426.txt
#   inflating: dataset/labels/speedbreaker427.txt
#   inflating: dataset/labels/speedbreaker428.txt
#   inflating: dataset/labels/speedbreaker429.txt
#   inflating: dataset/labels/speedbreaker43.txt
#   inflating: dataset/labels/speedbreaker430.txt
#   inflating: dataset/labels/speedbreaker431.txt
#   inflating: dataset/labels/speedbreaker432.txt
#   inflating: dataset/labels/speedbreaker433.txt
#   inflating: dataset/labels/speedbreaker434.txt
#   inflating: dataset/labels/speedbreaker435.txt
#   inflating: dataset/labels/speedbreaker436.txt
#   inflating: dataset/labels/speedbreaker437.txt
#   inflating: dataset/labels/speedbreaker438.txt
#   inflating: dataset/labels/speedbreaker439.txt
#   inflating: dataset/labels/speedbreaker44.txt
#   inflating: dataset/labels/speedbreaker440.txt
#   inflating: dataset/labels/speedbreaker441.txt
#   inflating: dataset/labels/speedbreaker442.txt
#   inflating: dataset/labels/speedbreaker443.txt
#   inflating: dataset/labels/speedbreaker444.txt
#   inflating: dataset/labels/speedbreaker445.txt
#   inflating: dataset/labels/speedbreaker446.txt
#   inflating: dataset/labels/speedbreaker447.txt
#   inflating: dataset/labels/speedbreaker448.txt
#   inflating: dataset/labels/speedbreaker449.txt
#   inflating: dataset/labels/speedbreaker45.txt
#   inflating: dataset/labels/speedbreaker450.txt
#   inflating: dataset/labels/speedbreaker451.txt
#   inflating: dataset/labels/speedbreaker452.txt
#   inflating: dataset/labels/speedbreaker453.txt
#   inflating: dataset/labels/speedbreaker454.txt
#   inflating: dataset/labels/speedbreaker455.txt
#   inflating: dataset/labels/speedbreaker456.txt
#   inflating: dataset/labels/speedbreaker457.txt
#   inflating: dataset/labels/speedbreaker458.txt
#   inflating: dataset/labels/speedbreaker459.txt
#   inflating: dataset/labels/speedbreaker46.txt
#   inflating: dataset/labels/speedbreaker460.txt
#   inflating: dataset/labels/speedbreaker461.txt
#   inflating: dataset/labels/speedbreaker462.txt
#   inflating: dataset/labels/speedbreaker463.txt
#   inflating: dataset/labels/speedbreaker464.txt
#   inflating: dataset/labels/speedbreaker465.txt
#   inflating: dataset/labels/speedbreaker466.txt
#   inflating: dataset/labels/speedbreaker467.txt
#   inflating: dataset/labels/speedbreaker468.txt
#   inflating: dataset/labels/speedbreaker469.txt
#   inflating: dataset/labels/speedbreaker47.txt
#   inflating: dataset/labels/speedbreaker470.txt
#   inflating: dataset/labels/speedbreaker471.txt
#   inflating: dataset/labels/speedbreaker472.txt
#   inflating: dataset/labels/speedbreaker473.txt
#   inflating: dataset/labels/speedbreaker474.txt
#   inflating: dataset/labels/speedbreaker475.txt
#   inflating: dataset/labels/speedbreaker476.txt
#   inflating: dataset/labels/speedbreaker477.txt
#   inflating: dataset/labels/speedbreaker478.txt
#   inflating: dataset/labels/speedbreaker479.txt
#   inflating: dataset/labels/speedbreaker48.txt
#   inflating: dataset/labels/speedbreaker480.txt
#   inflating: dataset/labels/speedbreaker481.txt
#   inflating: dataset/labels/speedbreaker482.txt
#   inflating: dataset/labels/speedbreaker483.txt
#   inflating: dataset/labels/speedbreaker484.txt
#   inflating: dataset/labels/speedbreaker485.txt
#   inflating: dataset/labels/speedbreaker486.txt
#   inflating: dataset/labels/speedbreaker487.txt
#   inflating: dataset/labels/speedbreaker488.txt
#   inflating: dataset/labels/speedbreaker489.txt
#   inflating: dataset/labels/speedbreaker49.txt
#   inflating: dataset/labels/speedbreaker490.txt
#   inflating: dataset/labels/speedbreaker491.txt
#   inflating: dataset/labels/speedbreaker492.txt
#   inflating: dataset/labels/speedbreaker493.txt
#   inflating: dataset/labels/speedbreaker494.txt
#   inflating: dataset/labels/speedbreaker495.txt
#   inflating: dataset/labels/speedbreaker496.txt
#   inflating: dataset/labels/speedbreaker497.txt
#   inflating: dataset/labels/speedbreaker498.txt
#   inflating: dataset/labels/speedbreaker499.txt
#   inflating: dataset/labels/speedbreaker5.txt
#   inflating: dataset/labels/speedbreaker50.txt
#   inflating: dataset/labels/speedbreaker500.txt
#   inflating: dataset/labels/speedbreaker501.txt
#   inflating: dataset/labels/speedbreaker502.txt
#   inflating: dataset/labels/speedbreaker503.txt
#   inflating: dataset/labels/speedbreaker504.txt
#   inflating: dataset/labels/speedbreaker505.txt
#   inflating: dataset/labels/speedbreaker506.txt
#   inflating: dataset/labels/speedbreaker507.txt
#   inflating: dataset/labels/speedbreaker508.txt
#   inflating: dataset/labels/speedbreaker509.txt
#   inflating: dataset/labels/speedbreaker51.txt
#   inflating: dataset/labels/speedbreaker510.txt
#   inflating: dataset/labels/speedbreaker511.txt
#   inflating: dataset/labels/speedbreaker512.txt
#   inflating: dataset/labels/speedbreaker513.txt
#   inflating: dataset/labels/speedbreaker514.txt
#   inflating: dataset/labels/speedbreaker515.txt
#   inflating: dataset/labels/speedbreaker516.txt
#   inflating: dataset/labels/speedbreaker517.txt
#   inflating: dataset/labels/speedbreaker518.txt
#   inflating: dataset/labels/speedbreaker519.txt
#   inflating: dataset/labels/speedbreaker52.txt
#   inflating: dataset/labels/speedbreaker520.txt
#   inflating: dataset/labels/speedbreaker521.txt
#   inflating: dataset/labels/speedbreaker522.txt
#   inflating: dataset/labels/speedbreaker523.txt
#   inflating: dataset/labels/speedbreaker524.txt
#   inflating: dataset/labels/speedbreaker525.txt
#   inflating: dataset/labels/speedbreaker526.txt
#   inflating: dataset/labels/speedbreaker527.txt
#   inflating: dataset/labels/speedbreaker528.txt
#   inflating: dataset/labels/speedbreaker529.txt
#   inflating: dataset/labels/speedbreaker53.txt
#   inflating: dataset/labels/speedbreaker530.txt
#   inflating: dataset/labels/speedbreaker531.txt
#   inflating: dataset/labels/speedbreaker532.txt
#   inflating: dataset/labels/speedbreaker533.txt
#   inflating: dataset/labels/speedbreaker534.txt
#   inflating: dataset/labels/speedbreaker535.txt
#   inflating: dataset/labels/speedbreaker536.txt
#   inflating: dataset/labels/speedbreaker537.txt
#   inflating: dataset/labels/speedbreaker538.txt
#   inflating: dataset/labels/speedbreaker539.txt
#   inflating: dataset/labels/speedbreaker54.txt
#   inflating: dataset/labels/speedbreaker540.txt
#   inflating: dataset/labels/speedbreaker541.txt
#   inflating: dataset/labels/speedbreaker542.txt
#   inflating: dataset/labels/speedbreaker543.txt
#   inflating: dataset/labels/speedbreaker544.txt
#   inflating: dataset/labels/speedbreaker545.txt
#   inflating: dataset/labels/speedbreaker546.txt
#   inflating: dataset/labels/speedbreaker547.txt
#   inflating: dataset/labels/speedbreaker548.txt
#   inflating: dataset/labels/speedbreaker549.txt
#   inflating: dataset/labels/speedbreaker55.txt
#   inflating: dataset/labels/speedbreaker550.txt
#   inflating: dataset/labels/speedbreaker551.txt
#   inflating: dataset/labels/speedbreaker552.txt
#   inflating: dataset/labels/speedbreaker553.txt
#   inflating: dataset/labels/speedbreaker554.txt
#   inflating: dataset/labels/speedbreaker555.txt
#   inflating: dataset/labels/speedbreaker556.txt
#   inflating: dataset/labels/speedbreaker557.txt
#   inflating: dataset/labels/speedbreaker558.txt
#   inflating: dataset/labels/speedbreaker559.txt
#   inflating: dataset/labels/speedbreaker56.txt
#   inflating: dataset/labels/speedbreaker560.txt
#   inflating: dataset/labels/speedbreaker561.txt
#   inflating: dataset/labels/speedbreaker562.txt
#   inflating: dataset/labels/speedbreaker563.txt
#   inflating: dataset/labels/speedbreaker564.txt
#   inflating: dataset/labels/speedbreaker565.txt
#   inflating: dataset/labels/speedbreaker566.txt
#   inflating: dataset/labels/speedbreaker567.txt
#   inflating: dataset/labels/speedbreaker568.txt
#   inflating: dataset/labels/speedbreaker569.txt
#   inflating: dataset/labels/speedbreaker57.txt
#   inflating: dataset/labels/speedbreaker570.txt
#   inflating: dataset/labels/speedbreaker571.txt
#   inflating: dataset/labels/speedbreaker572.txt
#   inflating: dataset/labels/speedbreaker573.txt
#   inflating: dataset/labels/speedbreaker574.txt
#   inflating: dataset/labels/speedbreaker575.txt
#   inflating: dataset/labels/speedbreaker576.txt
#   inflating: dataset/labels/speedbreaker577.txt
#   inflating: dataset/labels/speedbreaker578.txt
#   inflating: dataset/labels/speedbreaker579.txt
#   inflating: dataset/labels/speedbreaker58.txt
#   inflating: dataset/labels/speedbreaker580.txt
#   inflating: dataset/labels/speedbreaker581.txt
#   inflating: dataset/labels/speedbreaker582.txt
#   inflating: dataset/labels/speedbreaker583.txt
#   inflating: dataset/labels/speedbreaker584.txt
#   inflating: dataset/labels/speedbreaker585.txt
#   inflating: dataset/labels/speedbreaker586.txt
#   inflating: dataset/labels/speedbreaker587.txt
#   inflating: dataset/labels/speedbreaker588.txt
#   inflating: dataset/labels/speedbreaker589.txt
#   inflating: dataset/labels/speedbreaker59.txt
#   inflating: dataset/labels/speedbreaker590.txt
#   inflating: dataset/labels/speedbreaker591.txt
#   inflating: dataset/labels/speedbreaker592.txt
#   inflating: dataset/labels/speedbreaker593.txt
#   inflating: dataset/labels/speedbreaker594.txt
#   inflating: dataset/labels/speedbreaker595.txt
#   inflating: dataset/labels/speedbreaker596.txt
#   inflating: dataset/labels/speedbreaker597.txt
#   inflating: dataset/labels/speedbreaker598.txt
#   inflating: dataset/labels/speedbreaker599.txt
#   inflating: dataset/labels/speedbreaker6.txt
#   inflating: dataset/labels/speedbreaker60.txt
#   inflating: dataset/labels/speedbreaker600.txt
#   inflating: dataset/labels/speedbreaker601.txt
#   inflating: dataset/labels/speedbreaker602.txt
#   inflating: dataset/labels/speedbreaker603.txt
#   inflating: dataset/labels/speedbreaker61.txt
#   inflating: dataset/labels/speedbreaker62.txt
#   inflating: dataset/labels/speedbreaker63.txt
#   inflating: dataset/labels/speedbreaker64.txt
#   inflating: dataset/labels/speedbreaker65.txt
#   inflating: dataset/labels/speedbreaker66.txt
#   inflating: dataset/labels/speedbreaker67.txt
#   inflating: dataset/labels/speedbreaker68.txt
#   inflating: dataset/labels/speedbreaker69.txt
#   inflating: dataset/labels/speedbreaker7.txt
#   inflating: dataset/labels/speedbreaker70.txt
#   inflating: dataset/labels/speedbreaker71.txt
#   inflating: dataset/labels/speedbreaker72.txt
#   inflating: dataset/labels/speedbreaker73.txt
#   inflating: dataset/labels/speedbreaker74.txt
#   inflating: dataset/labels/speedbreaker75.txt
#   inflating: dataset/labels/speedbreaker76.txt
#   inflating: dataset/labels/speedbreaker77.txt
#   inflating: dataset/labels/speedbreaker78.txt
#   inflating: dataset/labels/speedbreaker79.txt
#   inflating: dataset/labels/speedbreaker8.txt
#   inflating: dataset/labels/speedbreaker80.txt
#   inflating: dataset/labels/speedbreaker81.txt
#   inflating: dataset/labels/speedbreaker82.txt
#   inflating: dataset/labels/speedbreaker83.txt
#   inflating: dataset/labels/speedbreaker84.txt
#   inflating: dataset/labels/speedbreaker85.txt
#   inflating: dataset/labels/speedbreaker86.txt
#   inflating: dataset/labels/speedbreaker87.txt
#   inflating: dataset/labels/speedbreaker88.txt
#   inflating: dataset/labels/speedbreaker89.txt
#   inflating: dataset/labels/speedbreaker9.txt
#   inflating: dataset/labels/speedbreaker90.txt
#   inflating: dataset/labels/speedbreaker91.txt
#   inflating: dataset/labels/speedbreaker92.txt
#   inflating: dataset/labels/speedbreaker93.txt
#   inflating: dataset/labels/speedbreaker94.txt
#   inflating: dataset/labels/speedbreaker95.txt
#   inflating: dataset/labels/speedbreaker96.txt
#   inflating: dataset/labels/speedbreaker97.txt
#   inflating: dataset/labels/speedbreaker98.txt
#   inflating: dataset/labels/speedbreaker99.txt
#   inflating: dataset/desktop.ini

# %%
dataset_path = Path('/content/dataset') # replace with 'path/to/dataset' for your custom data
labels = sorted(dataset_path.rglob("*labels/*.txt")) # all data in 'labels'

# %%
yaml_file = '/content/dataset/data.yaml'  # your data YAML with data directories and names dictionary
with open(yaml_file, 'r', encoding="utf8") as y:
    classes = yaml.safe_load(y)['names']
cls_idx = sorted(classes.keys())

# %%
indx = [l.stem for l in labels] # uses base filename as ID (no extension)
labels_df = pd.DataFrame([], columns=cls_idx, index=indx)

# %%
for label in labels:
    lbl_counter = Counter()

    with open(label,'r') as lf:
        lines = lf.readlines()

    for l in lines:
        # classes for YOLO label uses integer at first position of each line
        lbl_counter[int(l.split(' ')[0])] += 1

    labels_df.loc[label.stem] = lbl_counter

labels_df = labels_df.fillna(0.0) # replace `nan` values with `0.0`

# %%
ksplit = 3
kf = KFold(n_splits=ksplit, shuffle=True, random_state=20)   # setting random_state for repeatable results

kfolds = list(kf.split(labels_df))

# %%
folds = [f'split_{n}' for n in range(1, ksplit + 1)]
folds_df = pd.DataFrame(index=indx, columns=folds)

for idx, (train, val) in enumerate(kfolds, start=1):
    folds_df[f'split_{idx}'].loc[labels_df.iloc[train].index] = 'train'
    folds_df[f'split_{idx}'].loc[labels_df.iloc[val].index] = 'val'

# %%
fold_lbl_distrb = pd.DataFrame(index=folds, columns=cls_idx)

for n, (train_indices, val_indices) in enumerate(kfolds, start=1):
    train_totals = labels_df.iloc[train_indices].sum()
    val_totals = labels_df.iloc[val_indices].sum()

    # To avoid division by zero, we add a small value (1E-7) to the denominator
    ratio = val_totals / (train_totals + 1E-7)
    fold_lbl_distrb.loc[f'split_{n}'] = ratio

# %%
supported_extensions = ['.jpg', '.jpeg', '.png']

# Initialize an empty list to store image file paths
images = []

# Loop through supported extensions and gather image files
for ext in supported_extensions:
    images.extend(sorted((dataset_path / 'images').rglob(f"*{ext}")))

# Create the necessary directories and dataset YAML files (unchanged)
save_path = Path(dataset_path / f'{datetime.date.today().isoformat()}_{ksplit}-Fold_Cross-val')
save_path.mkdir(parents=True, exist_ok=True)
ds_yamls = []

for split in folds_df.columns:
    # Create directories
    split_dir = save_path / split
    split_dir.mkdir(parents=True, exist_ok=True)
    (split_dir / 'train' / 'images').mkdir(parents=True, exist_ok=True)
    (split_dir / 'train' / 'labels').mkdir(parents=True, exist_ok=True)
    (split_dir / 'val' / 'images').mkdir(parents=True, exist_ok=True)
    (split_dir / 'val' / 'labels').mkdir(parents=True, exist_ok=True)

    # Create dataset YAML files
    dataset_yaml = split_dir / f'{split}_dataset.yaml'
    ds_yamls.append(dataset_yaml)

    with open(dataset_yaml, 'w') as ds_y:
        yaml.safe_dump({
            'path': split_dir.as_posix(),
            'train': 'train',
            'val': 'val',
            'names': classes
        }, ds_y)

# %%
for image, label in zip(images, labels):
    for split, k_split in folds_df.loc[image.stem].items():
        # Destination directory
        img_to_path = save_path / split / k_split / 'images'
        lbl_to_path = save_path / split / k_split / 'labels'

        # Copy image and label files to new directory (SamefileError if file already exists)
        shutil.copy(image, img_to_path / image.name)
        shutil.copy(label, lbl_to_path / label.name)

# %%
folds_df.to_csv(save_path / "kfold_datasplit.csv")
fold_lbl_distrb.to_csv(save_path / "kfold_label_distribution.csv")

# %%
model = YOLO('yolov8s.pt', task='detect')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt to 'yolov8s.pt'...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 62.0MB/s]

# %%
#@title Utility to zip and download a directory
#@markdown Use this method to zip and download a directory. For ex. a TB logs
#@markdown directory or a checkpoint(s) directory.

from google.colab import files
import os

dir_to_zip = 'dir_name' #@param {type: "string"}
output_filename = 'file.zip' #@param {type: "string"}
delete_dir_after_download = "No"  #@param ['Yes', 'No']

os.system( "zip -r {} {}".format( output_filename , dir_to_zip ) )

if delete_dir_after_download == "Yes":
    os.system( "rm -r {}".format( dir_to_zip ) )

files.download( output_filename )

# %%
results = {}

# Define your additional arguments here
batch = 32
project = 'kfold_demo'
epochs = 20

for k in range(ksplit):
    dataset_yaml = ds_yamls[k]
    model.train(data=dataset_yaml,epochs=epochs, batch=batch, project=project)  # include any train arguments
    results[k] = model.metrics
# Out:
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/dataset/2023-10-08_3-Fold_Cross-val/split_1/split_1_dataset.yaml, epochs=20, patience=50, batch=32, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=kfold_demo, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=kfold_demo/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 24.5MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116822  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# Model summary: 225 layers, 11136374 parameters, 11136358 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir kfold_demo/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 111MB/s]
# AMP: checks passed ✅
# train: Scanning /content/dataset/2023-10-08_3-Fold_Cross-val/split_1/train/labels... 808 images, 0 backgrounds, 0 corrupt: 100%|██████████| 808/808 [00:00<00:00, 1857.77it/s]
# train: New cache created: /content/dataset/2023-10-08_3-Fold_Cross-val/split_1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/dataset/2023-10-08_3-Fold_Cross-val/split_1/val/labels... 405 images, 0 backgrounds, 0 corrupt: 100%|██████████| 405/405 [00:00<00:00, 1575.55it/s]
# val: New cache created: /content/dataset/2023-10-08_3-Fold_Cross-val/split_1/val/labels.cache
# Plotting labels to kfold_demo/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to kfold_demo/train
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20       7.6G      1.905      3.282      1.853         19        640: 100%|██████████| 26/26 [00:20<00:00,  1.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<00:00,  1.17it/s]
#                    all        405        673      0.352      0.308      0.234     0.0873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      7.84G      1.763      2.004      1.695         35        640: 100%|██████████| 26/26 [00:15<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<00:00,  1.13it/s]
#                    all        405        673     0.0738     0.0504    0.00932    0.00255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      7.93G      1.818      1.992      1.775         21        640: 100%|██████████| 26/26 [00:16<00:00,  1.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.56it/s]
#                    all        405        673      0.136      0.294     0.0791     0.0249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      7.85G      1.823      1.912       1.76         31        640: 100%|██████████| 26/26 [00:15<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00
🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/dataset/2023-10-08_3-Fold_Cross-val/split_2/split_2_dataset.yaml, epochs=20, patience=50, batch=32, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=kfold_demo, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.0, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=0.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=kfold_demo/train2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116822  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# Model summary: 225 layers, 11136374 parameters, 11136358 gradients, 28.6 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir kfold_demo/train2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/dataset/2023-10-08_3-Fold_Cross-val/split_2/train/labels... 809 images, 0 backgrounds, 0 corrupt: 100%|██████████| 809/809 [00:01<00:00, 709.80it/s]
# train: New cache created: /content/dataset/2023-10-08_3-Fold_Cross-val/split_2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/dataset/2023-10-08_3-Fold_Cross-val/split_2/val/labels... 404 images, 0 backgrounds, 0 corrupt: 100%|██████████| 404/404 [00:00<00:00, 608.92it/s]
# val: New cache created: /content/dataset/2023-10-08_3-Fold_Cross-val/split_2/val/labels.cache
# Plotting labels to kfold_demo/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to kfold_demo/train2
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20         8G      1.571      1.301      1.602          9        640: 100%|██████████| 26/26 [00:18<00:00,  1.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:03<00:00,  1.84it/s]
#                    all        404        590      0.757      0.745      0.811      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      8.07G      1.669      1.497      1.669          9        640: 100%|██████████| 26/26 [00:15<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.43it/s]
#                    all        404        590      0.611      0.575      0.619      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      8.07G      1.687      1.507      1.672         10        640: 100%|██████████| 26/26 [00:14<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.43it/s]
#                    all        404        590      0.542      0.552       0.53      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      8.08G      1.714      1.518      1.721         13        640: 100%|██████████| 26/26 [00:15<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.70it/s]
#                    all        404        590      0.542      0.456       0.46      0.208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      8.07G      1.768      1.693      1.745          9        640: 100%|██████████| 26/26 [00:14<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<00:00,  1.28it/s]
#                    all        404        590      0.515      0.497      0.495      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      8.07G      1.756      1.699      1.758         15        640: 100%|██████████| 26/26 [00:14<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<00:00,  1.37it/s]
#                    all        404        590      0.435      0.443      0.373      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      8.08G      1.736      1.567      1.738         19        640: 100%|██████████| 26/26 [00:15<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:03<00:00,  1.78it/s]
#                    all        404        590      0.551      0.533      0.534      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      8.08G      1.709      1.569      1.712         11        640: 100%|██████████| 26/26 [00:15<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<00:00,  1.25it/s]
#                    all        404        590      0.611      0.535      0.578      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      8.07G      1.681      1.521      1.711         21        640: 100%|██████████| 26/26 [00:15<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.64it/s]
#                    all        404        590      0.671      0.525      0.571      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      8.16G      1.657      1.456       1.67         14        640: 100%|██████████| 26/26 [00:15<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:03<00:00,  1.80it/s]
#                    all        404        590      0.623      0.546      0.601      0.285
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20       8.1G      1.596      1.416      1.618          9        640: 100%|██████████| 26/26 [00:19<00:00,  1.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.68it/s]
#                    all        404        590      0.665       0.62      0.617      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      8.12G      1.544      1.308      1.581         12        640: 100%|██████████| 26/26 [00:15<00:00,  1.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.60it/s]
#                    all        404        590      0.727      0.597      0.676       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      8.07G      1.546      1.274      1.584         13        640: 100%|██████████| 26/26 [00:14<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<00:00,  1.21it/s]
#                    all        404        590      0.719      0.621      0.685      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      8.17G       1.51      1.187      1.519         18        640: 100%|██████████| 26/26 [00:15<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.71it/s]
#                    all        404        590      0.742      0.622       0.72      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      8.07G      1.459      1.156      1.491         11        640: 100%|██████████| 26/26 [00:15<00:00,  1.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.46it/s]
#                    all        404        590      0.761       0.68      0.752      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      8.07G      1.428      1.136       1.48         14        640: 100%|██████████| 26/26 [00:14<00:00,  1.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<00:00,  1.37it/s]
#                    all        404        590      0.782      0.682      0.761      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      8.12G      1.399      1.089       1.46         18        640: 100%|██████████| 26/26 [00:15<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.67it/s]
#                    all        404        590      0.808      0.659      0.759      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      8.07G      1.351       1.04      1.407         12        640: 100%|██████████| 26/26 [00:15<00:00,  1.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<00:00,  1.26it/s]
#                    all        404        590      0.784      0.697      0.778      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      8.07G       1.35      1.015      1.428          9        640: 100%|██████████| 26/26 [00:14<00:00,  1.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.56it/s]
#                    all        404        590      0.779      0.708      0.781      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      8.11G      1.326     0.9817      1.389         10        640: 100%|██████████| 26/26 [00:15<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.66it/s]
#                    all        404        590      0.779      0.731      0.796      0.466
#
# 20 epochs completed in 0.118 hours.
# Optimizer stripped from kfold_demo/train2/weights/last.pt, 22.5MB
# Optimizer stripped from kfold_demo/train2/weights/best.pt, 22.5MB
#
# Validating kfold_demo/train2/weights/best.pt...
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:07<00:00,  1.13s/it]
#                    all        404        590      0.792      0.724      0.796      0.465
#                Pothole        404        374       0.77       0.66      0.755      0.449
#           Speedbreaker        404        216      0.815      0.787      0.837      0.481
# Speed: 1.9ms preprocess, 4.2ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to kfold_demo/train2
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/dataset/2023-10-08_3-Fold_Cross-val/split_3/split_3_dataset.yaml, epochs=20, patience=50, batch=32, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=kfold_demo, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.0, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=0.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=kfold_demo/train3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116822  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# Model summary: 225 layers, 11136374 parameters, 11136358 gradients, 28.6 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir kfold_demo/train3', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/dataset/2023-10-08_3-Fold_Cross-val/split_3/train/labels... 809 images, 0 backgrounds, 0 corrupt: 100%|██████████| 809/809 [00:01<00:00, 808.27it/s]
# train: New cache created: /content/dataset/2023-10-08_3-Fold_Cross-val/split_3/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/dataset/2023-10-08_3-Fold_Cross-val/split_3/val/labels... 404 images, 0 backgrounds, 0 corrupt: 100%|██████████| 404/404 [00:00<00:00, 526.07it/s]
# val: New cache created: /content/dataset/2023-10-08_3-Fold_Cross-val/split_3/val/labels.cache
# Plotting labels to kfold_demo/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to kfold_demo/train3
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      8.35G       1.42      1.122      1.482          9        640: 100%|██████████| 26/26 [00:17<00:00,  1.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.46it/s]
#                    all        404        593      0.848      0.731      0.862      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      8.42G      1.516      1.238      1.542         14        640: 100%|██████████| 26/26 [00:16<00:00,  1.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.69it/s]
#                    all        404        593      0.748      0.692      0.788      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      8.34G      1.486      1.248      1.546         14        640: 100%|██████████| 26/26 [00:15<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<00:00,  1.40it/s]
#                    all        404        593      0.728      0.692      0.735      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      8.39G      1.577      1.275      1.608         27        640: 100%|██████████| 26/26 [00:15<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.64it/s]
#                    all        404        593      0.671      0.637      0.673       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      8.34G      1.596      1.399      1.618         15        640: 100%|██████████| 26/26 [00:15<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:03<00:00,  1.77it/s]
#                    all        404        593      0.669      0.591       0.64      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      8.34G      1.567      1.376      1.596         13        640: 100%|██████████| 26/26 [00:15<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<00:00,  1.13it/s]
#                    all        404        593      0.705      0.594      0.662      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      8.34G      1.573      1.359      1.622         11        640: 100%|██████████| 26/26 [00:15<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#                    all        404        593      0.759      0.616      0.708      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      8.34G      1.533      1.262       1.58          9        640: 100%|██████████| 26/26 [00:15<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.75it/s]
#                    all        404        593      0.678      0.565      0.609      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      8.34G      1.506      1.269      1.554         19        640: 100%|██████████| 26/26 [00:14<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<00:00,  1.05it/s]
#                    all        404        593      0.693      0.607      0.642      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      8.34G      1.498      1.232      1.543         16        640: 100%|██████████| 26/26 [00:15<00:00,  1.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:03<00:00,  1.83it/s]
#                    all        404        593      0.709      0.616      0.675       0.34
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      8.34G      1.429      1.214      1.504         14        640: 100%|██████████| 26/26 [00:23<00:00,  1.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.51it/s]
#                    all        404        593      0.725      0.658      0.714      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      8.34G      1.459      1.157       1.53         12        640: 100%|██████████| 26/26 [00:16<00:00,  1.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.63it/s]
#                    all        404        593      0.763      0.685       0.75      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      8.34G      1.403        1.1      1.474          9        640: 100%|██████████| 26/26 [00:15<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<00:00,  1.20it/s]
#                    all        404        593      0.722      0.686      0.727      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      8.34G      1.358      1.025      1.426         12        640: 100%|██████████| 26/26 [00:15<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.70it/s]
#                    all        404        593      0.782      0.696      0.767      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      8.34G      1.316     0.9849      1.427          9        640: 100%|██████████| 26/26 [00:15<00:00,  1.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:05<00:00,  1.18it/s]
#                    all        404        593      0.782      0.663      0.748      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      8.34G      1.279     0.9727      1.388         21        640: 100%|██████████| 26/26 [00:16<00:00,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:03<00:00,  1.85it/s]
#                    all        404        593      0.774      0.733      0.786       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      8.43G      1.251     0.9147       1.36         18        640: 100%|██████████| 26/26 [00:14<00:00,  1.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.56it/s]
#                    all        404        593      0.842      0.718      0.804      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      8.34G      1.229     0.8872      1.344         11        640: 100%|██████████| 26/26 [00:15<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<00:00,  1.14it/s]
#                    all        404        593       0.84      0.725      0.815      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      8.34G      1.211     0.8726      1.338          9        640: 100%|██████████| 26/26 [00:15<00:00,  1.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.71it/s]
#                    all        404        593      0.849      0.759       0.83      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      8.34G      1.169     0.8246      1.305         42        640: 100%|██████████| 26/26 [00:15<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.66it/s]
#                    all        404        593      0.834      0.768      0.831       0.48
#
# 20 epochs completed in 0.130 hours.
# Optimizer stripped from kfold_demo/train3/weights/last.pt, 22.5MB
# Optimizer stripped from kfold_demo/train3/weights/best.pt, 22.5MB
#
# Validating kfold_demo/train3/weights/best.pt...
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:07<00:00,  1.13s/it]
#                    all        404        593      0.848      0.731       0.86      0.513
#                Pothole        404        355      0.861      0.731      0.863      0.541
#           Speedbreaker        404        238      0.834      0.731      0.858      0.486
# Speed: 2.1ms preprocess, 4.2ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to kfold_demo/train3

# %%
#@title Utility to zip and download a directory
#@markdown Use this method to zip and download a directory. For ex. a TB logs
#@markdown directory or a checkpoint(s) directory.

from google.colab import files
import os

dir_to_zip = '/content/kfold_demo' #@param {type: "string"}
output_filename = 'demo.zip' #@param {type: "string"}
delete_dir_after_download = "No"  #@param ['Yes', 'No']

os.system( "zip -r {} {}".format( output_filename , dir_to_zip ) )

if delete_dir_after_download == "Yes":
    os.system( "rm -r {}".format( dir_to_zip ) )

files.download( output_filename )
